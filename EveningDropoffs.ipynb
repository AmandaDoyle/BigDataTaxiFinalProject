# %%
import pandas as pd
pd.set_option('display.mpl_style', 'default')
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
dfe = pd.read_json("EveningDropoffs.json", orient="index")

# %%
dfe[2010.0]=(dfe[2010.0]-dfe[2010.0].mean())/dfe[2010.0].std()
dfe[2011.0]=(dfe[2011.0]-dfe[2011.0].mean())/dfe[2011.0].std()
dfe[2012.0]=(dfe[2012.0]-dfe[2012.0].mean())/dfe[2012.0].std()
dfe[2013.0]=(dfe[2013.0]-dfe[2013.0].mean())/dfe[2013.0].std()

# %%
dfe.dropna(inplace=True)

# %%
dfclean = dfe[dfe<dfe.quantile(0.95)]
dfclean.describe()
# Out:
#                2010          2011          2012          2013
# count  54493.000000  54492.000000  54493.000000  54493.000000
# mean      -0.172941     -0.172586     -0.175639     -0.176962
# std        0.126056      0.134659      0.149233      0.149739
# min       -0.221035     -0.224222     -0.233697     -0.234669
# 25%       -0.219371     -0.222520     -0.231883     -0.233046
# 50%       -0.215531     -0.218632     -0.227650     -0.229176
# 75%       -0.198250     -0.199795     -0.206484     -0.208949
# max        0.788774      0.826976      0.924261      0.910125

# %%
deltas = dfclean.pct_change(axis = 1)
deltas = deltas.drop(2010.0, axis = 1)
deltas.dropna()
deltas.describe(percentiles=[0.05, 0.1, 0.25, 0.5, 0.75, 0.85, 0.9, 0.95])
# Out:
#                2011          2012          2013
# count  54492.000000  54493.000000  54493.000000
# mean       0.041434     -0.089390     -0.011688
# std       15.508257     35.381052     14.855582
# min    -1177.458274  -7634.756431  -2436.555126
# 5%        -0.105488     -0.153507     -0.120802
# 10%       -0.024433     -0.014008     -0.022641
# 25%        0.007402      0.033608      0.000775
# 50%        0.014094      0.041770      0.005187
# 75%        0.019197      0.046988      0.011974
# 85%        0.025848      0.054552      0.022462
# 90%        0.036164      0.067022      0.039133
# 95%        0.099084      0.157637      0.123155
# max     2253.504142   2850.980977   2132.616227

# %%
deltas
# Out:
#            2011      2012      2013
# 0      0.014684  0.040813  0.002940
# 1     -0.013650 -0.046643 -0.076238
# 10     0.025349  0.033482  0.010703
# 100    0.015865  0.044062  0.000354
# 1000   0.011335  0.047453  0.003581
# 10000       NaN       NaN       NaN
# 10002  0.016771  0.036662  0.006484
# 10003 -0.189307  0.208189 -0.172140
# 10004  0.014494  0.041770  0.004651
# 10005  0.011156  0.045145  0.003061
# 10006       NaN       NaN       NaN
# 10007  0.006157  0.034697  0.013675
# 10008  0.027159  0.042047  0.011605
# 10009  0.146849  0.189621 -0.021351
# 1001   0.010855  0.045363  0.004551
# 10010  0.024877  0.041188  0.005415
# 10012  0.007813  0.044105  0.005387
# 10013  0.011192  0.044089  0.006765
# 10014  0.015894  0.028527 -0.004235
# 10015 -0.017560  0.065604  0.016650
# 10016  0.013767  0.040987  0.006066
# 10017 -0.003352  0.047013  0.014169
# 10018  0.022368  0.049736  0.009240
# 10019  0.013431  0.044550 -0.001734
# 1002   0.015258  0.035183  0.007437
# 10020  0.033993  0.076611 -0.005124
# 10021  0.033334 -0.001804  0.047883
# 10022  0.009575  0.045281  0.004594
# 10023  0.016648  0.029271 -0.002108
# 10024  0.006855  0.039998  0.011391
# ...         ...       ...       ...
# 9970   0.004354  0.044159  0.014579
# 9971   0.014419  0.042259  0.003626
# 9972  -0.060746 -0.359245 -0.579853
# 9973        NaN       NaN       NaN
# 9974   0.016535  0.038695  0.002309
# 9975  -0.420985 -0.006865 -0.033266
# 9976   0.018749  0.042927  0.001960
# 9977   0.026029  0.042042  0.010703
# 9978  -0.234363  0.230049  0.149616
# 9979   0.015045  0.037966  0.005639
# 998    0.011421  0.044594  0.010600
# 9980  -0.122808 -0.137893 -0.329724
# 9981   0.022152  0.044653  0.006484
# 9982   0.011697  0.034637  0.009602
# 9983   0.021638  0.049773  0.004102
# 9984   0.044390  0.046362  0.028254
# 9985  -0.002549  0.027768  0.009627
# 9986   0.014646  0.044035  0.001441
# 9987   0.010020  0.044089  0.006230
# 9988   0.007389  0.046820 -0.006572
# 999   -0.016955  0.061863  0.025043
# 9991        NaN       NaN       NaN
# 9992   0.017523  0.042901  0.005187
# 9993   0.024492  0.019418  0.001439
# 9994  -0.038125 -0.181965 -0.028748
# 9995   0.836381 -0.547225  0.397028
# 9996   0.040254  0.001240  0.021546
# 9997   0.013356  0.041795  0.003031
# 9998   0.007635  0.060659  0.004286
# 9999   0.507325  1.119112 -0.172419
#
# [57362 rows x 3 columns]

# %%
high_change = deltas[deltas>=deltas.quantile(0.95)]
high_change = high_change.dropna(how='all')
high_change
# Out:
#            2011      2012       2013
# 10003       NaN  0.208189        NaN
# 10009  0.146849  0.189621        NaN
# 10025  0.145567  0.420287   1.348825
# 10029  0.204015  0.361380        NaN
# 10032  0.366168       NaN        NaN
# 10034  0.683089       NaN   2.490281
# 10038  0.185909       NaN  27.785033
# 1004   0.179784  0.418359        NaN
# 10051       NaN       NaN   0.181475
# 10056  0.126293       NaN        NaN
# 10070       NaN       NaN   0.634009
# 10072  0.113181  0.224925   0.607969
# 10082  0.460569  0.587673   0.369699
# 10088  0.578315       NaN   0.458804
# 10104  0.195702       NaN        NaN
# 10111       NaN  0.366077        NaN
# 10113       NaN       NaN   0.565902
# 10115  0.676241  0.368728   0.471088
# 10128       NaN       NaN   0.143781
# 10139  0.472987  0.576470        NaN
# 10142  0.550717  0.360085   0.228165
# 10148       NaN       NaN   0.929469
# 1016        NaN       NaN   0.176486
# 10167       NaN       NaN   0.363985
# 10179  0.333757  0.256412        NaN
# 10214  0.108736  0.162000        NaN
# 10216       NaN  0.170609        NaN
# 10224       NaN  8.407042        NaN
# 10243  0.118501       NaN        NaN
# 1025   4.480065       NaN   0.271073
# ...         ...       ...        ...
# 9642        NaN       NaN   0.370289
# 9658   0.147165       NaN   0.123667
# 9675        NaN       NaN   0.274960
# 969    1.048669  0.655461        NaN
# 9707        NaN  1.026588   0.290395
# 9714        NaN  0.338245        NaN
# 973    0.115082       NaN        NaN
# 9732        NaN  0.319050        NaN
# 9740   0.117819       NaN        NaN
# 9767        NaN       NaN   0.196591
# 9778        NaN  0.228751   0.144540
# 978         NaN       NaN  19.620177
# 9781   0.165369       NaN        NaN
# 9796        NaN       NaN   0.124779
# 9807        NaN       NaN   0.145061
# 9827        NaN       NaN   0.286597
# 9859        NaN       NaN   0.449239
# 9871   0.173180       NaN        NaN
# 9872   0.149658       NaN   0.612827
# 9875        NaN  0.359556        NaN
# 9876   0.163757       NaN        NaN
# 9884        NaN  0.648950        NaN
# 9887        NaN  2.831211        NaN
# 9912   2.134306  1.249254        NaN
# 9926        NaN  0.272666        NaN
# 9929        NaN       NaN   0.169106
# 9933        NaN       NaN   2.074695
# 9978        NaN  0.230049   0.149616
# 9995   0.836381       NaN   0.397028
# 9999   0.507325  1.119112        NaN
#
# [5729 rows x 3 columns]

# %%
intersections = pd.read_csv('intersections.csv', header = None)

# %%
intersections.index.name = 'int_id'

high_change.index.name = 'int_id'

# %%
with_int = high_change.join(intersections)
with_int.to_csv('deltaswithint.csv')

# %%
deltas.to_csv('eveningdropoffschange.csv')

# %%
with_int.head()
# Out:
#             2011      2012      2013      0         1
# int_id
# 10003        NaN  0.208189       NaN  40.70157 -73.99332
# 10009   0.146849  0.189621       NaN  40.82145 -73.95038
# 10025   0.145567  0.420287  1.348825  40.71165 -73.96723
# 10029   0.204015  0.361380       NaN  40.84888 -73.93916
# 10032   0.366168       NaN       NaN  40.81980 -73.93679

# %%
with_int = with_int.rename(columns={2011.0: '2011change', 2012.0: '2012change', 2013.0: '2013change', 0.0: 'y', 1.0: 'x'})

# %%
dfe.head()
# Out:
#           2010      2011      2012      2013
# 0    -0.220139 -0.223371 -0.232488 -0.233171
# 1    -0.148842 -0.146810 -0.139962 -0.129292
# 10   -0.216427 -0.221913 -0.229343 -0.231798
# 100  -0.219883 -0.223371 -0.233213 -0.233296
# 1000 -0.220267 -0.222763 -0.233334 -0.234170

# %%
norm = with_int.join(dfe)
norm.head()
# Out:
#         2011change  2012change  2013change         y         x    2010.0  \
# int_id
# 10003          NaN    0.208189         NaN  40.70157 -73.99332  0.065050
# 10009     0.146849    0.189621         NaN  40.82145 -73.95038  0.188188
# 10025     0.145567    0.420287    1.348825  40.71165 -73.96723  0.211100
# 10029     0.204015    0.361380         NaN  40.84888 -73.93916  0.448544
# 10032     0.366168         NaN         NaN  40.81980 -73.93679 -0.077928
#
#           2011.0    2012.0    2013.0
# int_id
# 10003   0.052736  0.063714  0.052747
# 10009   0.215823  0.256748  0.251266
# 10025   0.241830  0.343468  0.806745
# 10029   0.540054  0.735219  0.668281
# 10032  -0.106463 -0.083721 -0.076228

# %%
df_not = pd.read_json("EveningDropoffs.json", orient="index")
df_not.dropna(inplace=True)

# %%
df_not.index.name = 'int_id'
df_not.head()
# Out:
#         2010  2011  2012  2013
# int_id
# 0          8     8    11    13
# 1        565   638   776   845
# 10        37    20    37    24
# 100       10     8     5    12
# 1000       7    13     4     5

# %%
total = with_int.join(df_not)
total.head()
# Out:
#         2011change  2012change  2013change         y         x  2010.0  \
# int_id
# 10003          NaN    0.208189         NaN  40.70157 -73.99332    2236
# 10009     0.146849    0.189621         NaN  40.82145 -73.95038    3198
# 10025     0.145567    0.420287    1.348825  40.71165 -73.96723    3377
# 10029     0.204015    0.361380         NaN  40.84888 -73.93916    5232
# 10032     0.366168         NaN         NaN  40.81980 -73.93679    1119
#
#         2011.0  2012.0  2013.0
# int_id
# 10003     2280    2460    2303
# 10009     3622    4056    3893
# 10025     3836    4773    8342
# 10029     6290    8012    7233
# 10032      970    1241    1270

# %%
total.to_csv('deltaswithcounts.csv')

# %%
elchange = with_int.drop('2012change', axis = 1)
elchange = elchange.drop('2013change', axis = 1)
elchange= elchange.dropna(how='any')
elchange.head()
# Out:
#         2011change         y         x
# int_id
# 10009     0.146849  40.82145 -73.95038
# 10025     0.145567  40.71165 -73.96723
# 10029     0.204015  40.84888 -73.93916
# 10032     0.366168  40.81980 -73.93679
# 10034     0.683089  40.75352 -73.93447

# %%
plt.hist(np.log(elchange['2011change']), bins = 40)
# Out:
# (array([ 332.,  349.,  292.,  243.,  237.,  252.,  206.,  160.,  143.,
#          119.,   88.,   63.,   52.,   39.,   41.,   18.,   17.,   16.,
#           11.,   11.,    8.,    4.,    7.,    6.,    0.,    1.,    1.,
#            2.,    2.,    2.,    0.,    0.,    0.,    0.,    0.,    1.,
#            0.,    0.,    0.,    2.]),
#  array([-2.31172113, -2.06092206, -1.81012299, -1.55932392, -1.30852485,
#         -1.05772578, -0.80692671, -0.55612764, -0.30532857, -0.0545295 ,
#          0.19626957,  0.44706864,  0.69786771,  0.94866679,  1.19946586,
#          1.45026493,  1.701064  ,  1.95186307,  2.20266214,  2.45346121,
#          2.70426028,  2.95505935,  3.20585842,  3.45665749,  3.70745656,
#          3.95825563,  4.2090547 ,  4.45985377,  4.71065284,  4.96145191,
#          5.21225098,  5.46305005,  5.71384912,  5.96464819,  6.21544726,
#          6.46624633,  6.7170454 ,  6.96784447,  7.21864354,  7.46944261,
#          7.72024168]),
#  <a list of 40 Patch objects>)
