# %%
import pandas as pd
pd.set_option('display.mpl_style', 'default')
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
dfe = pd.read_json("EveningDropoffs.json", orient="index")

# %%
dfe[2010.0]=(dfe[2010.0]-dfe[2010.0].mean())/dfe[2010.0].std()
dfe[2011.0]=(dfe[2011.0]-dfe[2011.0].mean())/dfe[2011.0].std()
dfe[2012.0]=(dfe[2012.0]-dfe[2012.0].mean())/dfe[2012.0].std()
dfe[2013.0]=(dfe[2013.0]-dfe[2013.0].mean())/dfe[2013.0].std()

# %%
dfe.dropna(inplace=True)
dfclean= dfe[[2010.0, 2012.0]]

# %%
deltas = dfclean.pct_change(axis = 1)
deltas = deltas.drop(2010.0, axis = 1)
deltas.dropna()
deltas.describe(percentiles=[0.05, 0.1, 0.25, 0.5, 0.75, 0.85, 0.9, 0.95])
# Out:
#                2012
# count  57362.000000
# mean      -0.007058
# std       20.323944
# min    -2858.081395
# 5%        -0.233998
# 10%       -0.048844
# 25%        0.044152
# 50%        0.056451
# 75%        0.062963
# 85%        0.073272
# 90%        0.092875
# 95%        0.262115
# max     2072.038754

# %%
high_change = deltas[deltas>=deltas.quantile(0.95)]
high_change = high_change.dropna(how='all')
high_change.describe(percentiles = [0.01, 0.25])
# Out:
#               2012
# count  2869.000000
# mean      4.423317
# std      49.113488
# min       0.262122
# 1%        0.264952
# 25%       0.419239
# 50%       0.728939
# max    2072.038754

# %%
intersections = pd.read_csv('intersections.csv', header = None)
with_int.head()
# Out:
#             2012      0         1
# int_id
# 10006   1.148569  40.76776 -73.99326
# 10009   0.364316  40.82145 -73.95038
# 10025   0.627035  40.71165 -73.96723
# 10029   0.639122  40.84888 -73.93916
# 1004    0.673357  40.80130 -73.95011

# %%
intersections['int_id']=intersections.index
high_change['int_id'] = high_change.index
high_change.head()
# Out:
#          2012.0  int_id
# 10006  1.148569   10006
# 10009  0.364316   10009
# 10025  0.627035   10025
# 10029  0.639122   10029
# 1004   0.673357    1004

# %%
with_int = pd.merge(high_change, intersections, on = 'int_id')
with_int.to_csv('deltaswithintnorm20102012.csv')
# with_int['int']=with_ints.index
with_int.head()
# Out:
#      2012.0  int_id         0         1
# 0  1.148569   10006  40.76776 -73.99326
# 1  0.364316   10009  40.82145 -73.95038
# 2  0.627035   10025  40.71165 -73.96723
# 3  0.639122   10029  40.84888 -73.93916
# 4  0.673357    1004  40.80130 -73.95011

# %%
re_filter = pd.read_csv('re_filter.csv')

# %%
intersections['int_id']=intersections.index
intersections.head()
# Out:
#           0         1  int_id
# 0  40.58937 -73.98092       0
# 1  40.70062 -73.93644       1
# 2  40.68191 -73.76634       2
# 3  40.67780 -73.93601       3
# 4  40.68809 -73.73571       4

# %%
re_withints = pd.merge(re_filter,intersections, left_on='Unnamed: 0', right_on = 'int_id')
re_withints.head()
# Out:
#    Unnamed: 0    2012.0         0         1  int_id
# 0          10  0.000000  40.84113 -73.84285      10
# 1       10007  0.970588  40.87860 -73.86912   10007
# 2       10021  0.453846  40.82075 -73.92610   10021
# 3       10036 -0.181818  40.70047 -73.88969   10036
# 4       10052  0.414634  40.80715 -73.90821   10052

# %%
re_withints.columns
#re_withints = re_withints.drop('2010.0', axis = 1)
#re_withints.to_csv('re_withints.csv')
# Out:
# Index([u'Unnamed: 0', u'2012.0', 0, 1, u'int_id'], dtype='object')

# %%
re_withints.head()
# Out:
#    Unnamed: 0    2012.0         0         1  int_id
# 0          10  0.000000  40.84113 -73.84285      10
# 1       10007  0.970588  40.87860 -73.86912   10007
# 3203         969  1.076214  40.72024 -73.94441     969
# 3206        9732  0.305158  40.80518 -73.95118    9732
#
# [261 rows x 5 columns]

# %%
in_both.to_csv('intsinboth.csv')

# %%
#in_both.columns
# Out:
# Index([u'Unnamed: 0', u'2012.0', 0, 1, u'int_id'], dtype='object')

# %%
#in_both[in_both[1]< -74.1]
# Out:
#       Unnamed: 0     2012.0         0         1
# 69         11080   0.274665  40.63719 -74.13030
# 116        11752   0.417923  40.55705 -74.12252
# 327        15683   0.415516  40.54669 -74.18590
# 371        16460   7.321939  40.52418 -74.23471
# 482        18325   0.453437  40.53111 -74.19676
# 504        18773   0.492985  40.50277 -74.23727
# 573        20073   0.547689  40.55770 -74.17200
# 804        24415   0.582251  40.52552 -74.18718
# 930        26687   1.720802  40.60068 -74.12143
# 992        27853   0.296257  40.57123 -74.13230
# 1088        2959   0.989581  40.60186 -74.11790
# 1098       29715   0.705668  40.60126 -74.13312
# 1126       30199   5.659989  40.63762 -74.10273
# 1169       30882   0.626060  40.62126 -74.10842
# 1201       31512   0.958234  40.54370 -74.17691
# 1518       37476   0.804773  40.54301 -74.19852
# 1519       37494   1.332571  40.61251 -74.10749
# 1545       38035   0.262870  40.61451 -74.17573
# 1551       38167   1.069904  40.61151 -74.18876
# 1620       39323   0.553505  40.55437 -74.18416
# 1739        4138   0.868213  40.60391 -74.11792
# 1752       41572   1.066950  40.60313 -74.13952
# 1932       44877   0.742705  40.62285 -74.14152
# 1941       45049   2.023584  40.62536 -74.16645
# 2085        4798   1.443164  40.56020 -74.11310
# 2188       49833   0.330100  40.58422 -74.14971
# 2221       50513   0.566404  40.59044 -74.13291
# 2305       51925   0.518767  40.50712 -74.25088
# 2348       52720   0.298188  40.62759 -74.17179
# 2558       55947   0.574753  40.63331 -74.16166
# 2627       57519  10.948500  40.58240 -74.15665
# 2714        5927   0.411208  40.51197 -74.25271
# 2786       60753   4.326497  40.52991 -74.21234
# 2998        9022   0.716828  40.53497 -74.23733

# %%
intersections[intersections.index==11080]
# Out:
#                0         1
# int_id
# 11080   40.84756 -73.93804

# %%
df = pd.read_csv('gentrifiedintspercentchange.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  2004price  2014price     change         0         1
# 0          10    3750000   11758010   2.135469  40.84113 -73.84285
# 1       10025    4276500   93422500  20.845551  40.71165 -73.96723
# 2       10032    2395000   15521754   5.480899  40.81980 -73.93679
# 3       10035    1370000   10639872   6.766330  40.71884 -73.85904
# 4       10036    1047000    9615000   8.183381  40.70047 -73.88969

# %%
deltas.head()
# Out:
#           2012
# 0     0.056096
# 1    -0.059656
# 10    0.059680
# 100   0.060626
# 1000  0.059326

# %%
deltas['int_id']=deltas.index
deltas.head()
# Out:
#         2012.0  int_id
# 0     0.056096       0
# 1    -0.059656       1
# 10    0.059680      10
# 100   0.060626     100
# 1000  0.059326    1000

# %%
df = pd.merge(df, deltas, right_on = 'int_id', left_on='Unnamed: 0')

# %%
df.head()
# Out:
#    Unnamed: 0  2004price  2014price     change         0         1    2012.0  \
# 0          10    3750000   11758010   2.135469  40.84113 -73.84285  0.059680
# 1       10025    4276500   93422500  20.845551  40.71165 -73.96723  0.627035
# 2       10032    2395000   15521754   5.480899  40.81980 -73.93679  0.074337
# 3       10035    1370000   10639872   6.766330  40.71884 -73.85904  0.047824
# 4       10036    1047000    9615000   8.183381  40.70047 -73.88969  0.087220
#
#    int_id
# 0      10
# 1   10025
# 2   10032
# 3   10035
# 4   10036

# %%
df.to_csv('taxisforgents.csv')
